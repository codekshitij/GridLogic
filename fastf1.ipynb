# %%
# !pip install fastf1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.5/135.5 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 49.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 7.0 MB/s eta 0:00:00
# ...

# %%
import fastf1

# %%
schedule = fastf1.get_event_schedule(2024)
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (24.0 KB) /root/.cache/fastf1
# WARNING:fastf1.fastf1.req:DEFAULT CACHE ENABLED! (24.0 KB) /root/.cache/fastf1

# %%
schedule
# Out:
#     RoundNumber               Country           Location  \
# 0             0               Bahrain             Sakhir
# 1             1               Bahrain             Sakhir
# 2             2          Saudi Arabia             Jeddah
# 3             3             Australia          Melbourne
# 4             4                 Japan             Suzuka
# 5             5                 China           Shanghai
# 6             6         United States              Miami
# 7             7                 Italy              Imola
# 8             8                Monaco             Monaco
# 9             9                Canada           Montréal
# 10           10                 Spain          Barcelona
# 11           11               Austria          Spielberg
# 12           12        United Kingdom        Silverstone
# 13           13               Hungary           Budapest
# 14           14               Belgium  Spa-Francorchamps
# ...

# %%
schedule['EventFormat']
# Out:
# 0               testing
# 1          conventional
# 2          conventional
# 3          conventional
# 4          conventional
# 5     sprint_qualifying
# 6     sprint_qualifying
# 7          conventional
# 8          conventional
# 9          conventional
# 10         conventional
# 11    sprint_qualifying
# 12         conventional
# 13         conventional
# 14         conventional
# 15         conventional
# 16         conventional
# 17         conventional
# 18         conventional
# 19    sprint_qualifying
# 20         conventional
# 21    sprint_qualifying
# 22         conventional
# 23    sprint_qualifying
# 24         conventional
# Name: EventFormat, dtype: object

# %%
schedule['conventional']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'conventional'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_398/2255117431.py in <cell line: 0>()
# ----> 1 schedule['conventional']
#
# ...
